# %%
from astroquery.mast import Observations
from ccdproc import ImageFileCollection
from astropy.table import Table
from astropy.io import fits
from astropy.io import ascii
from astropy.visualization import ZScaleInterval
from IPython.display import Image
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
from drizzlepac import tweakreg
from drizzlepac import astrodrizzle
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       config_testbed      imagefindpars           mapreg
#        photeq            pixreplace           pixtopix            pixtosky
#   refimagefindpars       resetbits          runastrodriz          skytopix
#      tweakback            tweakreg           updatenpol

# %%
lst_150 = glob.glob('F150LP/*/*flt.fits')
lst_165 = glob.glob('F165LP/*/*flt.fits')
lst_150
# Out:
# ['F150LP/57/hst_16231_57_acs_sbc_f150lp_jec457cm_flt.fits',
#  'F150LP/57/hst_16231_57_acs_sbc_f150lp_jec457cl_flt.fits',
#  'F150LP/57/hst_16231_57_acs_sbc_f150lp_jec457cn_flt.fits',
#  'F150LP/57/hst_16231_57_acs_sbc_f150lp_jec457co_flt.fits',
#  'F150LP/03/hst_16231_03_acs_sbc_f150lp_jec403ie_flt.fits',
#  'F150LP/03/hst_16231_03_acs_sbc_f150lp_jec403id_flt.fits',
#  'F150LP/03/hst_16231_03_acs_sbc_f150lp_jec403ib_flt.fits',
#  'F150LP/03/hst_16231_03_acs_sbc_f150lp_jec403ic_flt.fits',
#  'F150LP/04/hst_16231_04_acs_sbc_f150lp_jec404gw_flt.fits',
#  'F150LP/04/hst_16231_04_acs_sbc_f150lp_jec404gv_flt.fits',
#  'F150LP/04/hst_16231_04_acs_sbc_f150lp_jec404gy_flt.fits',
#  'F150LP/04/hst_16231_04_acs_sbc_f150lp_jec404gx_flt.fits',
#  'F150LP/56/hst_16231_56_acs_sbc_f150lp_jec456xp_flt.fits',
#  'F150LP/56/hst_16231_56_acs_sbc_f150lp_jec456xn_flt.fits',
#  'F150LP/56/hst_16231_56_acs_sbc_f150lp_jec456xo_flt.fits',
#  'F150LP/56/hst_16231_56_acs_sbc_f150lp_jec456xm_flt.fits',
#  'F150LP/10/hst_16231_10_acs_sbc_f150lp_jec410mn_flt.fits',
#  'F150LP/10/hst_16231_10_acs_sbc_f150lp_jec410mo_flt.fits',
#  'F150LP/10/hst_16231_10_acs_sbc_f150lp_jec410mm_flt.fits',
#  'F150LP/10/hst_16231_10_acs_sbc_f150lp_jec410ml_flt.fits',
#  'F150LP/07/hst_16231_07_acs_sbc_f150lp_jec407sj_flt.fits',
#  'F150LP/07/hst_16231_07_acs_sbc_f150lp_jec407sk_flt.fits',
#  'F150LP/07/hst_16231_07_acs_sbc_f150lp_jec407si_flt.fits',
#  'F150LP/07/hst_16231_07_acs_sbc_f150lp_jec407sh_flt.fits',
#  'F150LP/09/hst_16231_09_acs_sbc_f150lp_jec409i7_flt.fits',
#  'F150LP/09/hst_16231_09_acs_sbc_f150lp_jec409i9_flt.fits',
#  'F150LP/09/hst_16231_09_acs_sbc_f150lp_jec409i8_flt.fits',
#  'F150LP/09/hst_16231_09_acs_sbc_f150lp_jec409ia_flt.fits',
#  'F150LP/08/hst_16231_08_acs_sbc_f150lp_jec408i0_flt.fits',
#  'F150LP/08/hst_16231_08_acs_sbc_f150lp_jec408i1_flt.fits',
#  'F150LP/08/hst_16231_08_acs_sbc_f150lp_jec408i3_flt.fits',
#  'F150LP/08/hst_16231_08_acs_sbc_f150lp_jec408i2_flt.fits',
#  'F150LP/01/hst_16231_01_acs_sbc_f150lp_jec401nv_flt.fits',
#  'F150LP/01/hst_16231_01_acs_sbc_f150lp_jec401no_flt.fits',
#  'F150LP/01/hst_16231_01_acs_sbc_f150lp_jec401nx_flt.fits',
#  'F150LP/01/hst_16231_01_acs_sbc_f150lp_jec401nr_flt.fits']

# %%
def find_center(inputfilename):
    file = fits.open(inputfilename)
    #WCS info from header
    CRVAL1 = file[1].header['CRVAL1']
    CRVAL2 = file[1].header['CRVAL2']
    CRPIX1 = file[1].header['CRPIX1']
    CRPIX2 = file[1].header['CRPIX2']
    CD1_1 = file[1].header['CD1_1']
    CD1_2 = file[1].header['CD1_2']
    CD2_1 = file[1].header['CD2_1']
    CD2_2 = file[1].header['CD2_2']
    
    A = np.array([[CD1_1, CD1_2], [CD2_1, CD2_2]])
    A_inv = np.linalg.inv(A)
    B = np.array([[CRVAL1],[CRVAL2]])
    r0 = np.array([[CRPIX1],[CRPIX2]])
    
    def coo_pixtosky(r):
        return np.matmul(A, r-r0) + B
    
    def coo_skytopix(r_sky):
        return np.matmul(A_inv, r_sky - B) + r0
    
    #Target location info
    RA_TARG = file[0].header['RA_TARG'] 
    DEC_TARG = file[0].header['DEC_TARG']
    r_sky_TARG = np.array([[RA_TARG], [DEC_TARG]])
    X_TARG, Y_TARG = int(coo_skytopix(r_sky_TARG)[0]), int(coo_skytopix(r_sky_TARG)[1])
    
    data = file[1].data
    
    s = 100
    max_i = 0
    max_j = 0
    maxval = 0
    for i in range(Y_TARG-s, Y_TARG+s+1):
        for j in range(X_TARG-s, X_TARG+s+1):
            if data[i][j] > maxval:
                maxval = data[i][j]
                max_i = i
                max_j = j 
    r = 50
    total_flux = 0
    i_integral = 0
    j_integral = 0
    for i in range(max_i-r, max_i+r+1):
        for j in range(max_j-r, max_j+r+1):
            total_flux += data[i][j]
            i_integral += i*data[i][j]
            j_integral += j*data[i][j]
    
    i_center = i_integral/total_flux
    j_center = j_integral/total_flux
    
    X_center = j_center +1
    Y_center = i_center +1
    r_center = np.array([[X_center], [Y_center]])
    
    #print('X_center =', X_center)
    #print('Y_center =', Y_center)
    sky_coo_center = coo_pixtosky(r_center)
    #RA_center, DEC_center = sky_coo_center[0][0], sky_coo_center[1][0]
    return r_center, sky_coo_center

# %%
def avg_center(lst):
    a = np.array([[0.0],[0.0]])
    for item in lst:
        a += find_center(item)[1]
    return a/len(lst)

# %%
lst_150_nodc = []
for item in lst_150:
    file = fits.open(item)
    if file[1].header['MDECODT2'] < 25.0:
        lst_150_nodc.append(item)
lst_165_nodc = []
for item in lst_165:
    file = fits.open(item)
    if file[1].header['MDECODT2'] < 25.0:
        lst_165_nodc.append(item)
lst_165_nodc
# Out:
# ['F165LP/57/hst_16231_57_acs_sbc_f165lp_jec457cp_flt.fits',
#  'F165LP/03/hst_16231_03_acs_sbc_f165lp_jec403iu_flt.fits',
#  'F165LP/03/hst_16231_03_acs_sbc_f165lp_jec403is_flt.fits',
#  'F165LP/04/hst_16231_04_acs_sbc_f165lp_jec404gl_flt.fits',
#  'F165LP/04/hst_16231_04_acs_sbc_f165lp_jec404gr_flt.fits',
#  'F165LP/04/hst_16231_04_acs_sbc_f165lp_jec404go_flt.fits',
#  'F165LP/04/hst_16231_04_acs_sbc_f165lp_jec404gi_flt.fits',
#  'F165LP/56/hst_16231_56_acs_sbc_f165lp_jec456xj_flt.fits',
#  'F165LP/56/hst_16231_56_acs_sbc_f165lp_jec456xk_flt.fits',
#  'F165LP/56/hst_16231_56_acs_sbc_f165lp_jec456xl_flt.fits',
#  'F165LP/56/hst_16231_56_acs_sbc_f165lp_jec456xi_flt.fits',
#  'F165LP/10/hst_16231_10_acs_sbc_f165lp_jec410mj_flt.fits',
#  'F165LP/10/hst_16231_10_acs_sbc_f165lp_jec410mk_flt.fits',
#  'F165LP/10/hst_16231_10_acs_sbc_f165lp_jec410mi_flt.fits',
#  'F165LP/10/hst_16231_10_acs_sbc_f165lp_jec410mh_flt.fits',
#  'F165LP/08/hst_16231_08_acs_sbc_f165lp_jec408h8_flt.fits',
#  'F165LP/08/hst_16231_08_acs_sbc_f165lp_jec408h4_flt.fits',
#  'F165LP/08/hst_16231_08_acs_sbc_f165lp_jec408h5_flt.fits',
#  'F165LP/08/hst_16231_08_acs_sbc_f165lp_jec408hc_flt.fits']

# %%
#avg_center_150= avg_center(lst_150)
#avg_center_165= avg_center(lst_165)
#print(avg_center_150)
#print(avg_center_165)
avg_center_all = avg_center(lst_150+lst_165)
avg_center_all
# Out:
# array([[3.19600330e+02],
#        [2.91469478e-01]])

# %%
def new_CRVALs(inputfilename, ref_center):
    file = fits.open(inputfilename)
    #WCS info from header
    CRVAL1 = file[1].header['CRVAL1']
    CRVAL2 = file[1].header['CRVAL2']
    CRPIX1 = file[1].header['CRPIX1']
    CRPIX2 = file[1].header['CRPIX2']
    CD1_1 = file[1].header['CD1_1']
    CD1_2 = file[1].header['CD1_2']
    CD2_1 = file[1].header['CD2_1']
    CD2_2 = file[1].header['CD2_2']
    
    A = np.array([[CD1_1, CD1_2], [CD2_1, CD2_2]])
    r0 = np.array([[CRPIX1],[CRPIX2]])
    
    coo_center = find_center(inputfilename)
    r_center = coo_center[0]
    sky_coo_center = coo_center[1]
    
    new_CRVALs = ref_center - np.matmul(A, r_center - r0)
    return new_CRVALs

# %%
for item in lst_150_nodc:
    file = fits.open(item, mode = 'update')
    newname = file[0].header['ROOTNAME'][-5:]
    new_crvals = new_CRVALs(item, avg_center_all)
    for i in [1,2,3]:
        file[i].header['CRVAL1'] = new_crvals[0][0]
        file[i].header['CRVAL2'] = new_crvals[1][0]
    
    file.writeto(newname + '.fits', overwrite = True)

# %%
for item in lst_165_nodc:
    file = fits.open(item, mode = 'update')
    newname = file[0].header['ROOTNAME'][-5:]
    new_crvals = new_CRVALs(item, avg_center_all)
    for i in [1,2,3]:
        file[i].header['CRVAL1'] = new_crvals[0][0]
        file[i].header['CRVAL2'] = new_crvals[1][0]
    
    file.writeto(newname + '.fits', overwrite = True)

# %%
#lst_150_temp = []
#for item in lst_150:
#    lst_150_temp.append(item[42:46]+ 'q.fits')
#lst_165_temp = []
#for item in lst_165:
#    lst_165_temp.append(item[42:46]+ 'q.fits')

lst_150_nodc_temp = []
for item in lst_150_nodc:
    lst_150_nodc_temp.append(item[42:46] + 'q.fits')
lst_165_nodc_temp = []
for item in lst_165_nodc:
    lst_165_nodc_temp.append(item[42:46] + 'q.fits')

# %%
astrodrizzle.AstroDrizzle(lst_150_nodc_temp, 
                              output = 'F150LP_total_nodc_test11', 
                              clean = True,
                              build = True,
                              context = True,
                              runfile = 'F150LP_total_nodc_test10_drz.log',
                              num_cores = 1,
                              in_memory = False,
                              resetbits = 4096,
                              median = False,
                              static = False,
                              skysub = False,
                              driz_separate = False,
                              blot = False,
                              driz_cr = False,
                              final_bits = 0,
                              final_pixfrac = 0.6,
                              final_outnx=1947,
                              final_outny=1960, 
                              final_rot = 0.0,
                              final_scale = 0.025,
                              final_wcs = True)
# Out:
# Setting up logfile :  F150LP_total_nodc_test10_drz.log
# AstroDrizzle log file: F150LP_total_nodc_test10_drz.log
# AstroDrizzle Version 3.4.2 started at: 09:27:14.798 (14/06/2022)
#
# ==== Processing Step  Initialization  started at  09:27:14.801 (14/06/2022)
#
# Preserving original of:  57cmq.fits as  OrIg_files/57cmq.fits
# Preserving original of:  57clq.fits as  OrIg_files/57clq.fits
# Preserving original of:  57cnq.fits as  OrIg_files/57cnq.fits
# Preserving original of:  57coq.fits as  OrIg_files/57coq.fits
# Preserving original of:  03ieq.fits as  OrIg_files/03ieq.fits
# Preserving original of:  03idq.fits as  OrIg_files/03idq.fits
# Preserving original of:  03ibq.fits as  OrIg_files/03ibq.fits
# Preserving original of:  03icq.fits as  OrIg_files/03icq.fits
# Preserving original of:  07sjq.fits as  OrIg_files/07sjq.fits
# Preserving original of:  07skq.fits as  OrIg_files/07skq.fits
# Preserving original of:  07siq.fits as  OrIg_files/07siq.fits
# Preserving original of:  07shq.fits as  OrIg_files/07shq.fits
# Preserving original of:  01nvq.fits as  OrIg_files/01nvq.fits
# Preserving original of:  01noq.fits as  OrIg_files/01noq.fits
# Preserving original of:  01nrq.fits as  OrIg_files/01nrq.fits
# ##############################################################################
# #                                                                            #
# # “minmed” is highly recommended for three images,                           #
# #  and is good for four to six images,                                       #
# #  but should be avoided for ten or more images.                             #
# #                                                                            #
# ##############################################################################
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 319.6000200591268  0.2914196639319405
# CRPIX : 974.0  980.5
# CD1_1 CD1_2  : -6.944444444444443e-06  0.0
# CD2_1 CD2_2  : 0.0  6.944444444444443e-06
# NAXIS : 1947  1960
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 51 Mb.
# *  Output image size:       1947 X 1960 pixels.
# *  Output image file:       ~ 43 Mb.
# *  Cores available:         1
# *
# ********************************************************************************
# ==== Processing Step Initialization finished at 09:27:16.993 (14/06/2022)
# ==== Processing Step  Static Mask  started at  09:27:16.994 (14/06/2022)
#
# ==== Processing Step Static Mask finished at 09:27:16.995 (14/06/2022)
# ==== Processing Step  Subtract Sky  started at  09:27:16.996 (14/06/2022)
#
# ==== Processing Step Subtract Sky finished at 09:27:17.34 (14/06/2022)
# ==== Processing Step  Separate Drizzle  started at  09:27:17.347 (14/06/2022)
#
# ==== Processing Step Separate Drizzle finished at 09:27:17.348 (14/06/2022)
# ==== Processing Step  Create Median  started at  09:27:17.34 (14/06/2022)
#
# ==== Processing Step  Blot  started at  09:27:17.35 (14/06/2022)
#
# ==== Processing Step Blot finished at 09:27:17.351 (14/06/2022)
# ==== Processing Step  Driz_CR  started at  09:27:17.352 (14/06/2022)
#
# ==== Processing Step  Final Drizzle  started at  09:27:17.353 (14/06/2022)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 319.6000200591268  0.2914196639319405
# CRPIX : 974.0  980.5
# CD1_1 CD1_2  : -6.944444444444443e-06  0.0
# CD2_1 CD2_2  : 0.0  6.944444444444443e-06
# NAXIS : 1947  1960
# -Generating multi-extension output file:  F150LP_total_nodc_test11_drz.fits
# Deleted all instances of WCS with key A in extensions [1]
# Deleted all instances of WCS with key B in extensions [1]
# Writing out to disk: F150LP_total_nodc_test11_drz.fits
# ==== Processing Step Final Drizzle finished at 09:27:21.768 (14/06/2022)
#
# AstroDrizzle Version 3.4.2 is finished processing at 09:27:21.77 (14/06/2022).
#
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          2.1913 sec.
#             Static Mask          0.0010 sec.
#            Subtract Sky          0.3505 sec.
#        Separate Drizzle          0.0013 sec.
#           Create Median          0.0000 sec.
#                    Blot          0.0011 sec.
#                 Driz_CR          0.0000 sec.
#           Final Drizzle          4.4154 sec.
#    ====================          ====================
#                   Total          6.9607 sec.
#
# Trailer file written to:  F150LP_total_nodc_test10_drz.log

# %%
astrodrizzle.AstroDrizzle(lst_165_nodc_temp, 
                              output = 'F165LP_total_nodc_test10', 
                              clean = True,
                              build = True,
                              context = True,
                              runfile = 'F165LP_total_nodc_test10_drz.log',
                              num_cores = 1,
                              in_memory = False,
                              resetbits = 4096,
                              median = False,
                              static = False,
                              skysub = False,
                              driz_separate = False,
                              blot = False,
                              driz_cr = False,
                              final_bits = 0,
                              final_pixfrac = 0.6,
                              final_outnx=1947,
                              final_outny=1960, 
                              final_rot = 0.0,
                              final_scale = 0.025,
                              final_wcs = True)
# Out:
# Setting up logfile :  F165LP_total_nodc_test10_drz.log
# AstroDrizzle log file: F165LP_total_nodc_test10_drz.log
# AstroDrizzle Version 3.4.2 started at: 09:27:56.3 (14/06/2022)
#
# ==== Processing Step  Initialization  started at  09:27:56.381 (14/06/2022)
#
# Preserving original of:  04glq.fits as  OrIg_files/04glq.fits
# Preserving original of:  04goq.fits as  OrIg_files/04goq.fits
# Preserving original of:  04giq.fits as  OrIg_files/04giq.fits
# Preserving original of:  56xjq.fits as  OrIg_files/56xjq.fits
# Preserving original of:  56xkq.fits as  OrIg_files/56xkq.fits
# Preserving original of:  56xlq.fits as  OrIg_files/56xlq.fits
# Preserving original of:  56xiq.fits as  OrIg_files/56xiq.fits
# Preserving original of:  10mjq.fits as  OrIg_files/10mjq.fits
# Preserving original of:  10mkq.fits as  OrIg_files/10mkq.fits
# Preserving original of:  10miq.fits as  OrIg_files/10miq.fits
# Preserving original of:  10mhq.fits as  OrIg_files/10mhq.fits
# Preserving original of:  08h8q.fits as  OrIg_files/08h8q.fits
# Preserving original of:  08h4q.fits as  OrIg_files/08h4q.fits
# Preserving original of:  08h5q.fits as  OrIg_files/08h5q.fits
# Preserving original of:  08hcq.fits as  OrIg_files/08hcq.fits
# ##############################################################################
# #                                                                            #
# # “minmed” is highly recommended for three images,                           #
# #  and is good for four to six images,                                       #
# #  but should be avoided for ten or more images.                             #
# #                                                                            #
# ##############################################################################
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WARNING: No cte correction will be made for this SBC data.
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 319.6008632376901  0.29128568326698245
# CRPIX : 974.0  980.5
# CD1_1 CD1_2  : -6.944444444444444e-06  0.0
# CD2_1 CD2_2  : 0.0  6.944444444444444e-06
# NAXIS : 1947  1960
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 51 Mb.
# *  Output image size:       1947 X 1960 pixels.
# *  Output image file:       ~ 43 Mb.
# *  Cores available:         1
# *
# ********************************************************************************
# ==== Processing Step Initialization finished at 09:27:58.399 (14/06/2022)
# ==== Processing Step  Static Mask  started at  09:27:58.400 (14/06/2022)
#
# ==== Processing Step Static Mask finished at 09:27:58.401 (14/06/2022)
# ==== Processing Step  Subtract Sky  started at  09:27:58.402 (14/06/2022)
#
# ==== Processing Step Subtract Sky finished at 09:27:58.728 (14/06/2022)
# ==== Processing Step  Separate Drizzle  started at  09:27:58.728 (14/06/2022)
#
# ==== Processing Step Separate Drizzle finished at 09:27:58.729 (14/06/2022)
# ==== Processing Step  Create Median  started at  09:27:58.730 (14/06/2022)
#
# ==== Processing Step  Blot  started at  09:27:58.731 (14/06/2022)
#
# ==== Processing Step Blot finished at 09:27:58.732 (14/06/2022)
# ==== Processing Step  Driz_CR  started at  09:27:58.732 (14/06/2022)
#
# ==== Processing Step  Final Drizzle  started at  09:27:58.73 (14/06/2022)
#
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 319.6008632376901  0.29128568326698245
# CRPIX : 974.0  980.5
# CD1_1 CD1_2  : -6.944444444444444e-06  0.0
# CD2_1 CD2_2  : 0.0  6.944444444444444e-06
# NAXIS : 1947  1960
# -Generating multi-extension output file:  F165LP_total_nodc_test10_drz.fits
# Deleted all instances of WCS with key A in extensions [1]
# Deleted all instances of WCS with key B in extensions [1]
# Writing out to disk: F165LP_total_nodc_test10_drz.fits
# ==== Processing Step Final Drizzle finished at 09:28:02.850 (14/06/2022)
#
# AstroDrizzle Version 3.4.2 is finished processing at 09:28:02.851 (14/06/2022).
#
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          2.0188 sec.
#             Static Mask          0.0007 sec.
#            Subtract Sky          0.3259 sec.
#        Separate Drizzle          0.0009 sec.
#           Create Median          0.0000 sec.
#                    Blot          0.0012 sec.
#                 Driz_CR          0.0000 sec.
#           Final Drizzle          4.1165 sec.
#    ====================          ====================
#                   Total          6.4640 sec.
#
# Trailer file written to:  F165LP_total_nodc_test10_drz.log

# %%
final_150 = fits.open('F150LP_total_test10_drz.fits')
data_150 = final_150[1].data
final_165 = fits.open('F165LP_total_test10_drz.fits')
data_165 = final_165[1].data

# %%
coeff = 0.3
final_data = data_150 - coeff * data_165

# %%
final_150[1].data = final_data
file.writeto('subtracted3' + '.fits', overwrite = True)

# %%
raw = fits.open('jec401nxq_raw.fits')
raw[0].header
# Out:
# SIMPLE  =                    T / data conform to FITS standard
# BITPIX  =                   16 / bits per data value
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / File may contain standard extensions
# NEXTEND =                    3 / Number of standard extensions
# GROUPS  =                    F / image is in group format
# DATE    = '2022-04-13'         / date this file was written (yyyy-mm-dd)
# FILENAME= 'jec401nxq_raw.fits                     ' / name of file
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'ACS   '             / identifier for instrument used to acquire data
# EQUINOX =               2000.0 / equinox of celestial coord. system
#
#               / DATA DESCRIPTION KEYWORDS
#
# ROOTNAME= 'jec401nxq                         ' / rootname of the observation set
# IMAGETYP= 'EXT               ' / type of exposure identifier
# PRIMESI = 'ACS   '             / instrument designated as prime
#
#               / TARGET INFORMATION
#
# TARGNAME= 'SDSS-J211824.06+001729.4       ' / proposer's target name
# RA_TARG =   3.196002500000E+02 / right ascension of the target (deg) (J2000)
# DEC_TARG=   2.915000000000E-01 / declination of the target (deg) (J2000)
#
#               / PROPOSAL INFORMATION
#
# PROPOSID=                16231 / PEP proposal identifier
# LINENUM = '01.001         '    / proposal logsheet line number
# PR_INV_L= 'Rupke                         ' / last name of principal investigator
# PR_INV_F= 'David               ' / first name of principal investigator
# PR_INV_M= '                    ' / middle name / initial of principal investigat
#
#               / EXPOSURE INFORMATION
#
# SUNANGLE=           103.475021 / angle between sun and V1 axis
# MOONANGL=            65.298515 / angle between moon and V1 axis
# SUN_ALT =            60.097706 / altitude of the sun above Earth's limb
# FGSLOCK = 'FINE              ' / commanded FGS lock (FINE,COARSE,GYROS,UNKNOWN)
# GYROMODE= 'T'                  / number of gyros scheduled, T=3+OBAD
# REFFRAME= 'ICRS    '           / guide star catalog version
# MTFLAG  = ' '                  / moving target flag; T if it is a moving target
#
# DATE-OBS= '2021-05-27'         / UT date of start of observation (yyyy-mm-dd)
# TIME-OBS= '07:24:55'           / UT time of start of observation (hh:mm:ss)
# EXPSTART=   5.936130897789E+04 / exposure start time (Modified Julian Date)
# EXPEND  =   5.936131620752E+04 / exposure end time (Modified Julian Date)
# EXPTIME =           624.000000 / exposure duration (seconds)--calculated
# EXPFLAG = 'NORMAL       '      / Exposure interruption indicator
# QUALCOM1= '                                                                    '
# QUALCOM2= '                                                                    '
# QUALCOM3= '                                                                    '
# QUALITY = '                                                                    '
#
#
#               / POINTING INFORMATION
#
# PA_V3   =            56.999378 / position angle of V3-axis of HST (deg)
#
#               / TARGET OFFSETS (POSTARGS)
#
# POSTARG1=            -0.630000 / POSTARG in axis 1 direction
# POSTARG2=             0.051000 / POSTARG in axis 2 direction
#
#               / DIAGNOSTIC KEYWORDS
#
# PROCTIME=   5.968265256944E+04 / pipeline processing time (MJD)
# OPUS_VER= 'HSTDP 2022_1                ' / data processing software system versi
# AWSYSVER= 'v0.4.35 '           / cloud infrastructure package version
# AWSDPVER= 'v0.2.18 '           / cloud docker image version
# CSYS_VER= 'caldp_20220406'     / calibration software system version id
# CAL_VER = '                        ' / CALACS code version
#
#               / SCIENCE INSTRUMENT CONFIGURATION
#
# OBSTYPE = 'IMAGING       '     / observation type - imaging or spectroscopic
# OBSMODE = 'ACCUM     '         / operating mode
# CTEIMAGE= 'NONE'               / type of Charge Transfer Image, if applicable
# SCLAMP  = 'NONE          '     / lamp status, NONE or name of lamp which is on
# NRPTEXP =                    1 / number of repeat exposures in set: default 1
# SUBARRAY=                    F / data from a subarray (T) or full frame (F)
# DETECTOR= 'SBC'                / detector in use: WFC, HRC, or SBC
# FILTER1 = 'F150LP            ' / element selected from filter wheel 1
# FILTER2 = 'N/A               ' / element selected from filter wheel 2
# FW1OFFST=                    0 / computed filter wheel offset
# FW1ERROR=                    F / filter wheel position error flag
# FW2OFFST=                    0 / computed filter wheel offset
# FW2ERROR=                    F / filter wheel position error flag
# FWSOFFST=                    0 / computed filter wheel offset
# FWSERROR=                    F / filter wheel position error flag
# LRFWAVE =             0.000000 / proposed linear ramp filter wavelength
# APERTURE= 'SBC             '   / aperture name
# PROPAPER= 'SBC             '   / proposed aperture name
# DIRIMAGE= 'NONE     '          / direct image for grism or prism exposure
#
#               / MAMA OFFSETS
#
# MOFFSET1=                    0 / axis 1 MAMA offset (low-res pixels)
# MOFFSET2=                    0 / axis 2 MAMA offset (low-res pixels)
#
#               / LOCAL RATE CHECK IMAGE
#
# LRC_XSTS=                    F / Local Rate check image exists (T/F)
# LRC_FAIL=                    F / Local Rate Check Failed (T/F)
#
#               / CALIBRATION SWITCHES: PERFORM, OMIT, COMPLETE
#
# STATFLAG=                    F / Calculate statistics?
# WRTERR  =                    T / write out error array extension
# DQICORR = 'PERFORM '           / data quality initialization
# GLINCORR= 'PERFORM '           / correct for global detector non-linearities
# LFLGCORR= 'PERFORM '           / flag pixels for local and global nonlinearities
# PCTECORR= 'OMIT    '           / cte correction
# DARKCORR= 'OMIT    '           / Subtract dark image
# FLATCORR= 'PERFORM '           / flat field data
# PHOTCORR= 'PERFORM '           / populate photometric header keywords
# RPTCORR = 'OMIT    '           / add individual repeat observations
# DRIZCORR= 'PERFORM '           / drizzle processing
#
#               / CALIBRATION REFERENCE FILES
#
# BPIXTAB = 'jref$u451251ej_bpx.fits' / bad pixel table
# MLINTAB = 'jref$k9c13374j_lin.fits' / MAMA linearity correction table
# PCTETAB = 'N/A                    ' / CTE Correction Table
# DRKCFILE= 'N/A                    ' / De-trailed Dark Reference File
# DARKFILE= 'N/A                    ' / dark image file name
# PFLTFILE= 'jref$36h2201jj_pfl.fits' / pixel to pixel flat field file name
# DFLTFILE= 'N/A                    ' / delta flat field file name
# LFLTFILE= 'N/A                    ' / low order flat
# PHOTTAB = 'N/A                    ' / Photometric throughput table
# GRAPHTAB= 'N/A                    ' / the HST graph table
# COMPTAB = 'N/A                    ' / the HST components table
# IDCTAB  = 'jref$v6m2008mj_idc.fits' / image distortion correction table
# DGEOFILE= 'jref$s5f20000j_dxy.fits' / Distortion correction image
# MDRIZTAB= 'jref$ub215379j_mdz.fits' / MultiDrizzle parameter table
# CFLTFILE= 'N/A                    ' / Coronagraphic spot image
# SPOTTAB = 'N/A                    ' / Coronagraphic spot offset table
# IMPHTTAB= 'jref$64614292j_imp.fits' / Image Photometry Table
# D2IMFILE= 'N/A                    ' / Column Correction Reference File
# NPOLFILE= 'jref$xc215013j_npl.fits' / Non-polynomial Offsets Reference File
#
#               / OTFR KEYWORDS
#
# T_SGSTAR= '                  ' / OMS calculated guide star control
#
#               / PATTERN KEYWORDS
#
# PATTERN1= 'ACS-SBC-DITHER-BOX      ' / primary pattern type
# P1_SHAPE= 'PARALLELOGRAM     ' / primary pattern shape
# P1_PURPS= 'DITHER    '         / primary pattern purpose
# P1_NPTS =                    4 / number of points in primary pattern
# P1_PSPAC=             0.894773 / point spacing for primary pattern (arc-sec)
# P1_LSPAC=             0.587116 / line spacing for primary pattern (arc-sec)
# P1_ANGLE=            64.478514 / angle between sides of parallelogram patt (deg)
# P1_FRAME= 'POS-TARG '          / coordinate frame of primary pattern
# P1_ORINT=            20.151333 / orientation of pattern to coordinate frame (deg
# P1_CENTR= 'YES'                / center pattern relative to pointing (yes/no)
# PATTSTEP=                    4 / position number of this point in the pattern
#
#               / ASSOCIATION KEYWORDS
#
# ASN_ID  = 'JEC401010 '         / unique identifier assigned to association
# ASN_TAB = 'jec401010_asn.fits     ' / name of the association table
# ASN_MTYP= 'EXP-DTH     '       / Role of the Member in the Association
# CRDS_CTX= 'hst_1004.pmap'
# CRDS_VER= '11.9.0, b11.4.0, 64d96076d89b32a5687a6b77bb910ab93b3a99b3'
# ATODTAB = 'N/A     '
# BIASFILE= 'N/A     '
# CCDTAB  = 'N/A     '
# CRREJTAB= 'N/A     '
# FLSHFILE= 'N/A     '
# OSCNTAB = 'N/A     '
# SATUFILE= 'N/A     '
# SHADFILE= 'N/A     '
# SNKCFILE= 'N/A     '
