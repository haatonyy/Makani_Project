# %%
from astropy.io import fits

# %%
file150nx = fits.open('hst_16231_01_acs_sbc_f150lp_jec401nx_drz.fits')
file150nr = fits.open('hst_16231_01_acs_sbc_f150lp_jec401nr_drz.fits')
file150nv = fits.open('hst_16231_01_acs_sbc_f150lp_jec401nv_drz.fits')
file150no = fits.open('hst_16231_01_acs_sbc_f150lp_jec401no_drz.fits')

# %%
from astropy.wcs import WCS

# %%
file150nx.info()
# Out:
# Filename: hst_16231_01_acs_sbc_f150lp_jec401nx_drz.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     682   ()
#   1  SCI           1 ImageHDU        68   (1945, 1958)   float32
#   2  WHT           1 ImageHDU        44   (1945, 1958)   float32
#   3  CTX           1 ImageHDU        37   (1945, 1958)   int32
# ...

# %%
file150nr.info()
# Out:
# Filename: hst_16231_01_acs_sbc_f150lp_jec401nr_drz.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     682   ()
#   1  SCI           1 ImageHDU        68   (1945, 1958)   float32
#   2  WHT           1 ImageHDU        44   (1945, 1958)   float32
#   3  CTX           1 ImageHDU        37   (1945, 1958)   int32
# ...

# %%
file150nx[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1945
# NAXIS2  =                 1958
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INHERIT =                    T / inherit the primary header
# EXTNAME = 'SCI     '           / extension name
# EXTVER  =                    1
# BUNIT   = 'ELECTRONS/S'        / Units of science product
#
# CD1_1   = -6.9444445479247E-06
# CD1_2   =                  0.0
# CD2_1   =                  0.0
# CD2_2   = 6.94444454792473E-06
# CRVAL1  =    319.6010752954071
# CRVAL2  =   0.2919989632875474
# CRPIX1  =    973.0650521980209
# CRPIX2  =    978.5480888547237
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# ORIENTAT=                  0.0
# VAFACTOR=                  1.0
#               / World Coordinate System and Related Parameters
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
wcs = WCS(file[1].header)

# %%
data1 = file150nx[1].data
data2 = file150nr[1].data
data3 = file150nv[1].data
data4 = file150no[1].data

# %%
plt.grid(color='white', ls=':', alpha=0.7)
plt.imshow(data1)
plt.show()
plt.imshow(data2)
plt.grid(color='white', ls=':', alpha=0.7)

# %%
plt.grid(color='white', ls=':', alpha=0.7)
plt.imshow(data3)
plt.show()

# %%
plt.subplot(projection=wcs)
plt.imshow(data1)
plt.grid(color='white', ls=':', alpha=0.7)

# %%
plt.subplot(projection=wcs)
plt.imshow(data2)
plt.grid(color='white', ls=':', alpha=0.7)

# %%
import numpy as np

# %%
x = np.array([[1,2],[2,4]])

# %%
plt.imshow(data1[700:1000, 900:1200])
plt.show()
plt.imshow(data2[700:1000, 900:1200])
plt.show()
plt.imshow(data3[700:1000, 900:1200])
plt.show()

plt.imshow(data4[700:1000, 900:1200])

# %%
plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)
plt.show()

# %%
plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data1[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)
plt.show()

plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data2[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)
plt.show()

plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data3[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)
plt.show()

plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data3[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)

# %%
data_avg = (data1 + data2 + data3 + data4)/4

# %%
plt.figure(figsize = (7,7))
plt.subplot(projection=wcs)
plt.imshow(data_avg[890:925, 1035:1070])
plt.grid(color='white', ls=':', alpha=0.7)
